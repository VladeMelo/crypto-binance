# %%
import pandas as pd

# %%
df = pd.read_csv('70-30 LGBM Drawdown.csv')

# %%
df['profit_total'] = df['profit_1'] + df['profit_0']

# %%
df.sort_values(by='profit_total', ascending=False)
# Out:
#       n_estimators  num_leaves  learning_rate   k  threshold  profit_1  \
# 5314           150          31            0.1  11       0.40  1.273315
# 3430           100          31            0.1  12       0.35  1.241028
# 3633           100          31            0.2  11       0.35  1.238638
# 3424           100          31            0.1  11       0.40  1.186942
# 4887           150          20            0.2  10       0.40  1.186081
# ...            ...         ...            ...  ..        ...       ...
# 2141           100           5            0.1   7       0.65 -0.076408
# 4052           150           5            0.1  10       0.65 -0.079082
# 475             50           5            0.2   9       0.65 -0.091365
# 2357           100           5            0.2   8       0.60 -0.091534
# 300             50           5            0.1  14       0.65 -0.119892
#
#       max_drawdown_1  profit_0  max_drawdown_0  profit_total
# ...

# %%
df.sort_values(by='profit_1', ascending=False)[:20]
# Out:
#       n_estimators  num_leaves  learning_rate   k  threshold  profit_1  \
# 5314           150          31           0.10  11       0.40  1.273315
# 3430           100          31           0.10  12       0.35  1.241028
# 3633           100          31           0.20  11       0.35  1.238638
# 3424           100          31           0.10  11       0.40  1.186942
# 4887           150          20           0.20  10       0.40  1.186081
# 5320           150          31           0.10  12       0.35  1.176072
# 4264           150           5           0.20  11       0.40  1.161977
# 3634           100          31           0.20  11       0.40  1.157870
# 5551           150          31           0.20  15       0.35  1.156135
# 3017           100          20           0.20  13       0.35  1.153297
# 1744            50          31           0.20  11       0.40  1.143075
# 1759            50          31           0.20  13       0.45  1.127854
# ...
